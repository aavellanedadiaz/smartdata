# %% [markdown]
# ![mental_health_banner_1774025040503.jpg](../mental_health_banner_1774025040503.jpg "mental_health_banner_1774025040503.jpg")

# %% [markdown]
# ### Preparacion Ambiente
#
# Notebook de preparacion de ambiente

# %%
dbutils.widgets.removeAll()
dbutils.widgets.text("storageName","saafadproject")
storageName = dbutils.widgets.get("storageName")

# %%
spark.sql(f"""CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-raw`
URL 'abfss://raw@{storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para las tablas raw del Data Lake';""")

spark.sql(f"""CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-bronze`
URL 'abfss://bronze@{storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para las tablas bronze del Data Lake';""")

spark.sql(f"""CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-silver`
URL 'abfss://silver@{storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para las tablas silver del Data Lake';""")

spark.sql(f"""CREATE EXTERNAL LOCATION IF NOT EXISTS `exlt-gold`
URL 'abfss://gold@{storageName}.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL credential)
COMMENT 'Ubicación externa para las tablas gold del Data Lake';""")

# %%
catalog_name = "health_db_catalog"
spark.sql(f"DROP CATALOG IF EXISTS {catalog_name} CASCADE;")
spark.sql(f"""CREATE CATALOG IF NOT EXISTS {catalog_name}
COMMENT 'Catalogo para la arquitectura medallion del ambiente en dev';""")

# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS health_db_catalog.raw;")
spark.sql("CREATE SCHEMA IF NOT EXISTS health_db_catalog.bronze;")
spark.sql("CREATE SCHEMA IF NOT EXISTS health_db_catalog.silver;")
spark.sql("CREATE SCHEMA IF NOT EXISTS health_db_catalog.gold;")

# %% [markdown]
# ### Bronze

# %%
spark.sql(f"""
          CREATE OR REPLACE TABLE health_db_catalog.bronze.us_state_codes
          (
            id INTEGER,
            state STRING,
            ingestion_date TIMESTAMP
          )
          USING DELTA
          LOCATION 'abfss://bronze@{storageName}.dfs.core.windows.net/us_state_codes'
          """)

# %%
spark.sql(f"""
          CREATE OR REPLACE TABLE health_db_catalog.bronze.patients_information
          (
            person_id INTEGER,
            gender STRING,
            age INTEGER,
            occupation STRING,
            state INTEGER,
            ingestion_date TIMESTAMP
          )
          USING DELTA
          LOCATION 'abfss://bronze@{storageName}.dfs.core.windows.net/patients_information'
          """)

# %%
spark.sql(f"""
          CREATE OR REPLACE TABLE health_db_catalog.bronze.daily_nutrition_facts
          (
            person_id INTEGER,
            dialy_vitamins STRING,
            ingestion_date TIMESTAMP
          )
          USING DELTA
          LOCATION 'abfss://bronze@{storageName}.dfs.core.windows.net/daily_nutrition_facts'
          """)

# %%
spark.sql(f"""
          CREATE OR REPLACE TABLE health_db_catalog.bronze.temperature
          (
            state_id INTEGER,
            state STRING,
            month INTEGER,
            year INTEGER,
            avg_temp DECIMAL(3,1),
            ingestion_date TIMESTAMP
          )
          USING DELTA
          LOCATION 'abfss://bronze@{storageName}.dfs.core.windows.net/temperature'
          """)

# %%
spark.sql(f"""
          CREATE OR REPLACE TABLE health_db_catalog.bronze.healthy_lifestyle
          (
            person_id INTEGER,
            sleep_duration DECIMAL(2,1),
            quality_of_sleep INTEGER,
            physical_activity_level INTEGER,
            stress_level INTEGER,
            BMI_category STRING,
            blood_pressure STRING,
            hearth_rate INTEGER,
            daily_steps INTEGER,
            sleep_disorder STRING,
            ingestion_date TIMESTAMP
          )
          USING DELTA
          LOCATION 'abfss://bronze@{storageName}.dfs.core.windows.net/healthy_lifestyle'
          """)

# %% [markdown]
# ### Silver

# %%
spark.sql(f"""
          CREATE OR REPLACE TABLE health_db_catalog.silver.quality_sleep
          (
            person_id INTEGER,
            state STRING,
            gender STRING,
            age INTEGER,
            occupation STRING,
            vitaminD INTEGER,
            vitaminB12 INTEGER,
            vitaminC INTEGER,
            sleep_disorder STRING
          )
          USING DELTA
          LOCATION 'abfss://silver@{storageName}.dfs.core.windows.net/quality_sleep'
          """)

# %%
spark.sql(f"""
          CREATE OR REPLACE TABLE health_db_catalog.silver.lifestyle_habits
          (
            person_id INTEGER,
            state STRING,
            gender STRING,
            age INTEGER,
            occupation STRING,
            vitaminD INTEGER,
            vitaminB12 INTEGER,
            vitaminC INTEGER,
            vitaminA INTEGER,
            vitaminE INTEGER,
            vitaminK INTEGER,
            folate INTEGER,
            iron INTEGER,
            calcium INTEGER,
            magnesium INTEGER,
            physical_activity_level INTEGER
          )
          USING DELTA
          LOCATION 'abfss://silver@{storageName}.dfs.core.windows.net/lifestyle_habits'
          """)

# %%
spark.sql(f"""
          CREATE OR REPLACE TABLE health_db_catalog.silver.nutrition
          (
            person_id INTEGER,
            state STRING,
            gender STRING,
            age INTEGER,
            occupation STRING,
            vitaminD INTEGER,
            vitaminB12 INTEGER,
            vitaminC INTEGER,
            vitaminA INTEGER,
            vitaminE INTEGER,
            vitaminK INTEGER,
            folate INTEGER,
            iron INTEGER,
            calcium INTEGER,
            magnesium INTEGER,
            BMI_category STRING
          )
          USING DELTA
          LOCATION 'abfss://silver@{storageName}.dfs.core.windows.net/nutrition'
          """)

# %%
spark.sql(f"""
          CREATE OR REPLACE TABLE health_db_catalog.silver.temperature
          (
            state_id INTEGER,
            state STRING,
            month INTEGER,
            year INTEGER,
            avg_temp DECIMAL(3,1)
          )
          USING DELTA
          LOCATION 'abfss://silver@{storageName}.dfs.core.windows.net/temperature'
          """)

# %% [markdown]
# ### Gold

# %%
spark.sql(f"""
          CREATE OR REPLACE TABLE health_db_catalog.gold.mental_health_disorders_by_health
          (
            state STRING,
            mental_health_disorders_count INTEGER
          )
          USING DELTA
          LOCATION 'abfss://gold@{storageName}.dfs.core.windows.net/mental_health_disorders_by_health'
          """)
