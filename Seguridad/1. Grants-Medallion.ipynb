-- %% [markdown]
-- ##Grants On Tables

-- %%
-- Bronze
GRANT SELECT ON TABLE health_db_catalog.bronze.us_state_codes TO `afad_1990_bog_col@outlook.com`;
GRANT SELECT ON TABLE health_db_catalog.bronze.patients_information TO `afad_1990_bog_col@outlook.com`;
GRANT SELECT ON TABLE health_db_catalog.bronze.daily_nutrition_facts TO `afad_1990_bog_col@outlook.com`;
GRANT SELECT ON TABLE health_db_catalog.bronze.temperature TO `afad_1990_bog_col@outlook.com`;
GRANT SELECT ON TABLE health_db_catalog.bronze.healthy_lifestyle TO `afad_1990_bog_col@outlook.com`;

-- Silver
GRANT SELECT ON TABLE health_db_catalog.silver.quality_sleep TO `afad_1990_bog_col@outlook.com`;
GRANT SELECT ON TABLE health_db_catalog.silver.lifestyle_habits TO `afad_1990_bog_col@outlook.com`;
GRANT SELECT ON TABLE health_db_catalog.silver.nutrition TO `afad_1990_bog_col@outlook.com`;
GRANT SELECT ON TABLE health_db_catalog.silver.temperature TO `afad_1990_bog_col@outlook.com`;

-- Gold
GRANT SELECT ON TABLE health_db_catalog.gold.mental_health_disorders_by_health TO `afad_1990_bog_col@outlook.com`;

-- %% [markdown]
-- ##Grants On Catalog

-- %%
GRANT USE CATALOG ON CATALOG health_db_catalog TO `afad_1990_bog_col@outlook.com`;

-- %% [markdown]
-- ##Grants On Schemas

-- %%
GRANT USE SCHEMA ON SCHEMA health_db_catalog.raw TO `afad_1990_bog_col@outlook.com`;
GRANT USE SCHEMA ON SCHEMA health_db_catalog.bronze TO `afad_1990_bog_col@outlook.com`;
GRANT USE SCHEMA ON SCHEMA health_db_catalog.silver TO `afad_1990_bog_col@outlook.com`;
GRANT USE SCHEMA ON SCHEMA health_db_catalog.gold TO `afad_1990_bog_col@outlook.com`;

-- %% [markdown]
-- ## Creating Groups

-- %%
CREATE GROUP `data_engineers`;

-- %%
ALTER GROUP `data_engineers`
ADD USER `afad_1990_bog_col@outlook.com`;
