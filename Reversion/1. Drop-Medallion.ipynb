-- %%
%python
dbutils.widgets.removeAll()
dbutils.widgets.text("nameStorage","saafadproject")
dbutils.widgets.text("catalogo","health_db_catalog")

-- %% [markdown]
-- ### Eliminacion Tablas Bronze

-- %%
-- DROP TABLES
DROP TABLE IF EXISTS ${catalogo}.bronze.us_state_codes;
DROP TABLE IF EXISTS ${catalogo}.bronze.patients_information;
DROP TABLE IF EXISTS ${catalogo}.bronze.daily_nutrition_facts;
DROP TABLE IF EXISTS ${catalogo}.bronze.daily_nutrition_facts;
DROP TABLE IF EXISTS ${catalogo}.bronze.temperature;

-- %%
%python
## REMOVE DATA (Bronze)
dbutils.fs.rm(f"bronze/tablas/us_state_codes", True)
dbutils.fs.rm(f"bronze/tablas/patients_information", True)
dbutils.fs.rm(f"bronze/tablas/daily_nutrition_facts", True)
dbutils.fs.rm(f"bronze/tablas/daily_nutrition_facts", True)
dbutils.fs.rm(f"bronze/tablas/temperature", True)

-- %% [markdown]
-- ### Eliminacion tablas Silver

-- %%
-- DROP TABLES
DROP TABLE IF EXISTS ${catalogo}.silver.quality_sleep;
DROP TABLE IF EXISTS ${catalogo}.silver.lifestyle_habits;
DROP TABLE IF EXISTS ${catalogo}.silver.nutrition;
DROP TABLE IF EXISTS ${catalogo}.silver.temperature

-- %%
%python
# REMOVE DATA (Silver)
dbutils.fs.rm(f"silver/tablas/quality_sleep", True)
dbutils.fs.rm(f"silver/tablas/lifestyle_habits", True)
dbutils.fs.rm(f"silver/tablas/nutrition", True)
dbutils.fs.rm(f"silver/tablas/temperature", True)

-- %% [markdown]
-- ### Eliminacion tablas Golden

-- %%
-- DROP TABLES
DROP TABLE IF EXISTS ${catalogo}.gold.mental_health_disorders_by_health;

-- %%
%python
# REMOVE DATA (Gold)
dbutils.fs.rm(f"gold/tablas/mental_health_disorders_by_health", True)
